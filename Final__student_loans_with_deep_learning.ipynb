# %% [markdown]
# # Student Loan Risk with Deep Learning

# %%
# Imports
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from pathlib import Path

# %% [markdown]
# ---
#
# ## Prepare the data to be used on a neural network model

# %% [markdown]
# ### Step 1: Read the `student-loans.csv` file into a Pandas DataFrame. Review the DataFrame, looking for columns that could eventually define your features and target variables.

# %%
# Read the csv into a Pandas DataFrame
file_path = "https://static.bc-edx.com/ai/ail-v-1-0/m18/lms/datasets/student-loans.csv"
loans_df = pd.read_csv(file_path)

# Review the DataFrame
loans_df.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score  credit_ranking
# 0                  9.4               0
# 1                  9.8               0
# 2                  9.8               0
# 3                  9.8               1
# 4                  9.4               0

# %%
# Review the data types associated with the columns
loans_df.dtypes
# Out:
# payment_history           float64
# location_parameter        float64
# stem_degree_score         float64
# gpa_ranking               float64
# alumni_success            float64
# study_major_code          float64
# time_to_completion        float64
# finance_workshop_score    float64
# cohort_ranking            float64
# total_loan_score          float64
# financial_aid_score       float64
# credit_ranking              int64
# dtype: object

# %%
# Check the credit_ranking value counts
loans_df["credit_ranking"].value_counts()
# Out:
# 1    855
# 0    744
# Name: credit_ranking, dtype: int64

# %% [markdown]
# ### Step 2: Using the preprocessed data, create the features (`X`) and target (`y`) datasets. The target dataset should be defined by the preprocessed DataFrame column “credit_ranking”. The remaining columns should define the features dataset.

# %%
# Define the target set y using the credit_ranking column
y = loans_df["credit_ranking"]

# Display a sample of y
print(y[:5])
# Out:
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0
# Name: credit_ranking, dtype: int64

# %%
# Define features set X by selecting all columns but credit_ranking
X = loans_df.drop("credit_ranking", axis=1)

# Review the features DataFrame
X.head()
# Out:
#    payment_history  location_parameter  stem_degree_score  gpa_ranking  \
# 0              7.4                0.70               0.00          1.9
# 1              7.8                0.88               0.00          2.6
# 2              7.8                0.76               0.04          2.3
# 3             11.2                0.28               0.56          1.9
# 4              7.4                0.70               0.00          1.9
#
#    alumni_success  study_major_code  time_to_completion  \
# 0           0.076              11.0                34.0
# 1           0.098              25.0                67.0
# 2           0.092              15.0                54.0
# 3           0.075              17.0                60.0
# 4           0.076              11.0                34.0
#
#    finance_workshop_score  cohort_ranking  total_loan_score  \
# 0                  0.9978            3.51              0.56
# 1                  0.9968            3.20              0.68
# 2                  0.9970            3.26              0.65
# 3                  0.9980            3.16              0.58
# 4                  0.9978            3.51              0.56
#
#    financial_aid_score
# 0                  9.4
# 1                  9.8
# 2                  9.8
# 3                  9.8
# 4                  9.4

# %% [markdown]
# ### Step 3: Split the features and target sets into training and testing datasets.

# %%
# Split the preprocessed data into a training and testing dataset
# Assign the function a random_state equal to 1

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ### Step 4: Use scikit-learn's `StandardScaler` to scale the features data.

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the scaler to the features training dataset
scaler.fit(X_train)

# Transform the features of the X training and testing datasets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# ---
#
# ## Compile and Evaluate a Model Using a Neural Network

# %% [markdown]
# ### Step 1: Create a deep neural network by assigning the number of input features, the number of layers, and the number of neurons on each layer using Tensorflow’s Keras.
#
# > **Hint** You can start with a two-layer deep neural network model that uses the `relu` activation function for both layers.

# %%
# Define the the number of inputs (features) to the model
# Get the number of features
n_features = X_train_scaled.shape[1]


# Review the number of features
n_features
# Out:
# 11

# %%
number_input_features = len(X_train_scaled[0])

# Define the number of hidden nodes for the first hidden layer
first_hidden_layer_nodes = 6

# Define the number of hidden nodes for the second hidden layer
second_hidden_layer_nodes = 3

# Define the number of neurons in the output layer. ... 1

# %%
# Create the Sequential model instance
nn = tf.keras.models.Sequential()

# Add the first hidden layer with its input layer
nn.add(
    tf.keras.layers.Dense(units=first_hidden_layer_nodes, input_dim=number_input_features, activation="relu")
)

# Add the second hidden layer
nn.add(tf.keras.layers.Dense(units=second_hidden_layer_nodes, activation="relu"))

# Add the output layer to the model specifying the number of output neurons and activation function
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# %%
# Display the Sequential model summary
nn.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 6)                 72
#
#  dense_22 (Dense)            (None, 3)                 21
#
#  dense_23 (Dense)            (None, 1)                 4
#
# =================================================================
# Total params: 97 (388.00 Byte)
# Trainable params: 97 (388.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Step 2: Compile and fit the model using the `binary_crossentropy` loss function, the `adam` optimizer, and the `accuracy` evaluation metric.

# %%
# Compile the Sequential model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Fit the model using 50 epochs and the training data
fit_model = nn.fit(X_train_scaled,y_train,epochs=50)
# Out:
# Epoch 1/50
# 38/38 [==============================] - 1s 2ms/step - loss: 0.7177 - accuracy: 0.4654
# Epoch 2/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6867 - accuracy: 0.5021
# Epoch 3/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6699 - accuracy: 0.5838
# Epoch 4/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6586 - accuracy: 0.6480
# Epoch 5/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6495 - accuracy: 0.6631
# Epoch 6/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6422 - accuracy: 0.6881
# Epoch 7/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6352 - accuracy: 0.6972
# Epoch 8/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6293 - accuracy: 0.7031
# Epoch 9/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6238 - accuracy: 0.7173
# Epoch 10/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6185 - accuracy: 0.7214
# Epoch 11/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6141 - accuracy: 0.7264
# Epoch 12/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6095 - accuracy: 0.7273
# Epoch 13/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6054 - accuracy: 0.7314
# Epoch 14/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.6019 - accuracy: 0.7331
# Epoch 15/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5980 - accuracy: 0.7356
# Epoch 16/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5943 - accuracy: 0.7364
# Epoch 17/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5913 - accuracy: 0.7398
# Epoch 18/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5881 - accuracy: 0.7389
# Epoch 19/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5851 - accuracy: 0.7398
# Epoch 20/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5823 - accuracy: 0.7423
# Epoch 21/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5796 - accuracy: 0.7440
# Epoch 22/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5768 - accuracy: 0.7465
# Epoch 23/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5744 - accuracy: 0.7473
# Epoch 24/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5720 - accuracy: 0.7490
# Epoch 25/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5692 - accuracy: 0.7498
# Epoch 26/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5664 - accuracy: 0.7481
# Epoch 27/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5633 - accuracy: 0.7498
# Epoch 28/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5597 - accuracy: 0.7490
# Epoch 29/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5554 - accuracy: 0.7473
# Epoch 30/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5497 - accuracy: 0.7440
# Epoch 31/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5434 - accuracy: 0.7473
# Epoch 32/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5379 - accuracy: 0.7498
# Epoch 33/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5327 - accuracy: 0.7473
# Epoch 34/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5283 - accuracy: 0.7465
# Epoch 35/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5250 - accuracy: 0.7490
# Epoch 36/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5222 - accuracy: 0.7515
# Epoch 37/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5201 - accuracy: 0.7515
# Epoch 38/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5178 - accuracy: 0.7498
# Epoch 39/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5160 - accuracy: 0.7515
# Epoch 40/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5148 - accuracy: 0.7506
# Epoch 41/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5128 - accuracy: 0.7498
# Epoch 42/50
# 38/38 [==============================] - 0s 3ms/step - loss: 0.5119 - accuracy: 0.7490
# Epoch 43/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5112 - accuracy: 0.7498
# Epoch 44/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5102 - accuracy: 0.7515
# Epoch 45/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5091 - accuracy: 0.7523
# Epoch 46/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5086 - accuracy: 0.7515
# Epoch 47/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5081 - accuracy: 0.7523
# Epoch 48/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5068 - accuracy: 0.7548
# Epoch 49/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5063 - accuracy: 0.7523
# Epoch 50/50
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5048 - accuracy: 0.7540

# %% [markdown]
# ### Step 3: Evaluate the model using the test data to determine the model’s loss and accuracy.

# %%
# Evaluate the model loss and accuracy metrics using the evaluate method and the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)

# Display the model loss and accuracy results
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 13/13 - 0s - loss: 0.5267 - accuracy: 0.7225 - 141ms/epoch - 11ms/step
# Loss: 0.5267242789268494, Accuracy: 0.7225000262260437

# %% [markdown]
# ### Step 4: Save and export your model to a keras file, and name the file `student_loans.keras`.

# %%
# Set the model's file path
path = Path("./Final_student_loans_with_deep_learning.keras")

# Export your model to a keras file
nn.save(path)

# %% [markdown]
# ---
# ## Predict Loan Repayment Success by Using your Neural Network Model

# %% [markdown]
# ### Step 1: Reload your saved model.

# %%
# Set the model's file path
file_path = Path("./Final_student_loans_with_deep_learning.keras")

# Load the model to a new object
nn_imported = tf.keras.models.load_model(file_path)

# %% [markdown]
# ### Step 2: Make predictions on the testing data and save the predictions to a DataFrame.

# %%
# Make predictions with the test data
predictions = nn_imported.predict(X_test_scaled)

# predictions = nn_imported.predict(X_test_scaled[:len(y_test)])

# Display a sample of the predictions
predictions
# Out:
# 13/13 [==============================] - 0s 2ms/step
# array([[0.52130806],
#        [0.37867063],
#        [0.8628241 ],
#        [0.7155654 ],
#        [0.92499727],
#        [0.8101286 ],
#        [0.9264321 ],
#        [0.2432571 ],
#        [0.6029523 ],
#        [0.39523524],
#        [0.84127903],
#        [0.35164362],
#        [0.530628  ],
#        [0.87934077],
#        [0.5529253 ],
#        [0.35167095],
#        [0.77646863],
#        [0.4329178 ],
#        [0.6532446 ],
#        [0.32469994],
#        [0.34683377],
#        [0.81376594],
#        [0.34689918],
#        [0.94412386],
#        [0.39109227],
#        [0.849567  ],
#        [0.86010456],
#        [0.5884336 ],
#        [0.26049566],
#        [0.20260762],
#        [0.50661916],
#        [0.9287828 ],
#        [0.19382362],
#        [0.8902813 ],
#        [0.11897146],
#        [0.43156374],
#        [0.31520835],
#        [0.40171078],
#        [0.8296745 ],
#        [0.24610656],
#        [0.85728335],
#        [0.08947319],
#        [0.17306048],
#        [0.8524588 ],
#        [0.10429871],
#        [0.71086097],
#        [0.19087608],
#        [0.45604742],
#        [0.28136268],
#        [0.8333505 ],
#        [0.22973639],
#        [0.3461021 ],
#        [0.8998285 ],
#        [0.05315819],
#        [0.1535646 ],
#        [0.8372319 ],
#        [0.86587286],
#        [0.88696396],
#        [0.4288825 ],
#        [0.18227214],
#        [0.91056234],
#        [0.1480512 ],
#        [0.35886928],
#        [0.45567372],
#        [0.02829584],
#        [0.33512807],
#        [0.9107409 ],
#        [0.6353673 ],
#        [0.42609948],
#        [0.9378839 ],
#        [0.11897146],
#        [0.87049544],
#        [0.45037514],
#        [0.57021666],
#        [0.3608641 ],
#        [0.4562216 ],
#        [0.87479967],
#        [0.25457183],
#        [0.4598561 ],
#        [0.788105  ],
#        [0.8017746 ],
#        [0.14581013],
#        [0.07301431],
#        [0.3612023 ],
#        [0.5855293 ],
#        [0.10663366],
#        [0.1928982 ],
#        [0.88475287],
#        [0.42509228],
#        [0.78254336],
#        [0.2086732 ],
#        [0.8970208 ],
#        [0.13675366],
#        [0.920295  ],
#        [0.90421766],
#        [0.28025156],
#        [0.9182483 ],
#        [0.5686306 ],
#        [0.38680488],
#        [0.848675  ],
#        [0.582471  ],
#        [0.33236352],
#        [0.2248797 ],
#        [0.09285756],
#        [0.10516209],
#        [0.45102698],
#        [0.7884485 ],
#        [0.47751242],
#        [0.84954536],
#        [0.335236  ],
#        [0.9218967 ],
#        [0.5053438 ],
#        [0.8390004 ],
#        [0.5079925 ],
#        [0.3649538 ],
#        [0.93833125],
#        [0.24108674],
#        [0.10305678],
#        [0.21593697],
#        [0.24652915],
#        [0.15077297],
#        [0.9454984 ],
#        [0.8819969 ],
#        [0.220145  ],
#        [0.31918648],
#        [0.60662323],
#        [0.6309124 ],
#        [0.15962692],
#        [0.88883287],
#        [0.7697983 ],
#        [0.68354666],
#        [0.23405875],
#        [0.8888427 ],
#        [0.09707112],
#        [0.7944203 ],
#        [0.8293793 ],
#        [0.16605072],
#        [0.93810934],
#        [0.35481662],
#        [0.3242487 ],
#        [0.31165817],
#        [0.4698716 ],
#        [0.5267938 ],
#        [0.27823946],
#        [0.8630722 ],
#        [0.9224726 ],
#        [0.6570016 ],
#        [0.05502061],
#        [0.7722665 ],
#        [0.7672305 ],
#        [0.4628153 ],
#        [0.90529096],
#        [0.18838419],
#        [0.3002468 ],
#        [0.8692176 ],
#        [0.9197314 ],
#        [0.92132413],
#        [0.87392026],
#        [0.85463655],
#        [0.41352543],
#        [0.9047733 ],
#        [0.5729637 ],
#        [0.24737465],
#        [0.15438437],
#        [0.91598624],
#        [0.80781966],
#        [0.511621  ],
#        [0.12913468],
#        [0.08759551],
#        [0.8330908 ],
#        [0.29805678],
#        [0.80889326],
#        [0.11359961],
#        [0.4271432 ],
#        [0.9353706 ],
#        [0.34343705],
#        [0.55132884],
#        [0.12758867],
#        [0.41486394],
#        [0.2802516 ],
#        [0.6872898 ],
#        [0.9135479 ],
#        [0.66651297],
#        [0.16073164],
#        [0.90130794],
#        [0.88136166],
#        [0.84132725],
#        [0.5202492 ],
#        [0.38798642],
#        [0.11591996],
#        [0.49076167],
#        [0.5970502 ],
#        [0.35012046],
#        [0.10580891],
#        [0.8296831 ],
#        [0.36512026],
#        [0.60401195],
#        [0.5868182 ],
#        [0.32549194],
#        [0.33845887],
#        [0.85678846],
#        [0.5976088 ],
#        [0.9076594 ],
#        [0.2004446 ],
#        [0.9349098 ],
#        [0.8580328 ],
#        [0.3111597 ],
#        [0.05282934],
#        [0.84610873],
#        [0.7568379 ],
#        [0.277038  ],
#        [0.74457866],
#        [0.2248797 ],
#        [0.9193492 ],
#        [0.29211554],
#        [0.16100901],
#        [0.25014356],
#        [0.17823999],
#        [0.86575544],
#        [0.54062295],
#        [0.60546774],
#        [0.3336384 ],
#        [0.2570307 ],
#        [0.14867334],
#        [0.8307615 ],
#        [0.6535429 ],
#        [0.2626756 ],
#        [0.6492047 ],
#        [0.934686  ],
#        [0.440139  ],
#        [0.36625847],
#        [0.26086658],
#        [0.8808077 ],
#        [0.8355878 ],
#        [0.3248377 ],
#        [0.17800155],
#        [0.9148548 ],
#        [0.16111526],
#        [0.5139218 ],
#        [0.426842  ],
#        [0.83220524],
#        [0.8688603 ],
#        [0.7358146 ],
#        [0.4424621 ],
#        [0.4476117 ],
#        [0.9474939 ],
#        [0.5887105 ],
#        [0.33342588],
#        [0.1279999 ],
#        [0.34141153],
#        [0.14462529],
#        [0.2984127 ],
#        [0.92294663],
#        [0.75918096],
#        [0.8795905 ],
#        [0.13757476],
#        [0.1481999 ],
#        [0.1730959 ],
#        [0.18846956],
#        [0.8514559 ],
#        [0.8610121 ],
#        [0.42594594],
#        [0.6929045 ],
#        [0.38761494],
#        [0.40446135],
#        [0.7722665 ],
#        [0.6479829 ],
#        [0.16444634],
#        [0.07851452],
#        [0.893229  ],
#        [0.23949173],
#        [0.62716216],
#        [0.13167992],
#        [0.9008833 ],
#        [0.10533535],
#        [0.51226974],
#        [0.38341784],
#        [0.80889326],
#        [0.59301335],
#        [0.21054335],
#        [0.9619865 ],
#        [0.5641352 ],
#        [0.62695986],
#        [0.07625062],
#        [0.22247787],
#        [0.8122864 ],
#        [0.33735532],
#        [0.46732166],
#        [0.14091833],
#        [0.70405465],
#        [0.51418775],
#        [0.77646863],
#        [0.4792656 ],
#        [0.5081294 ],
#        [0.9068011 ],
#        [0.85642505],
#        [0.15157808],
#        [0.90111274],
#        [0.13019489],
#        [0.23687454],
#        [0.49759647],
#        [0.84149575],
#        [0.08222182],
#        [0.77767915],
#        [0.46505526],
#        [0.548867  ],
#        [0.06760884],
#        [0.8590796 ],
#        [0.602414  ],
#        [0.05975359],
#        [0.32882625],
#        [0.6156312 ],
#        [0.48458838],
#        [0.9140289 ],
#        [0.59784997],
#        [0.65759474],
#        [0.2426757 ],
#        [0.31307393],
#        [0.8656861 ],
#        [0.9148548 ],
#        [0.3094263 ],
#        [0.5695638 ],
#        [0.92650187],
#        [0.17439768],
#        [0.36512026],
#        [0.50995445],
#        [0.17629245],
#        [0.9531032 ],
#        [0.7968328 ],
#        [0.5756893 ],
#        [0.76597476],
#        [0.16212174],
#        [0.36070547],
#        [0.5317382 ],
#        [0.40047342],
#        [0.17049187],
#        [0.87528974],
#        [0.9193492 ],
#        [0.31709027],
#        [0.5489327 ],
#        [0.21881256],
#        [0.37192118],
#        [0.63979346],
#        [0.55803365],
#        [0.49519286],
#        [0.9374079 ],
#        [0.8438684 ],
#        [0.456784  ],
#        [0.27742362],
#        [0.47681573],
#        [0.74457866],
#        [0.94383126],
#        [0.5745346 ],
#        [0.86664844],
#        [0.5020168 ],
#        [0.24432337],
#        [0.94292265],
#        [0.87934077],
#        [0.16605072],
#        [0.03416165],
#        [0.16381016],
#        [0.84877187],
#        [0.31431916],
#        [0.93788135],
#        [0.20828982],
#        [0.19198148],
#        [0.40350717],
#        [0.251643  ],
#        [0.82748455],
#        [0.17800155],
#        [0.6986725 ],
#        [0.6326815 ],
#        [0.42513096],
#        [0.3001057 ],
#        [0.2310864 ],
#        [0.6333889 ],
#        [0.9590996 ],
#        [0.9426572 ],
#        [0.16100901],
#        [0.8619267 ],
#        [0.87371564],
#        [0.83923   ],
#        [0.9270357 ],
#        [0.67307013],
#        [0.47384074],
#        [0.9286291 ],
#        [0.16963108],
#        [0.81022644],
#        [0.79571354],
#        [0.4663769 ],
#        [0.21851039],
#        [0.47731778],
#        [0.2704133 ],
#        [0.7198115 ],
#        [0.22861771],
#        [0.7242427 ],
#        [0.42509228],
#        [0.8808077 ],
#        [0.3156986 ],
#        [0.49446893]], dtype=float32)

# %%
# Save the "predictions" to a DataFrame and round the predictions to binary result

binary_predictions = np.round(predictions).flatten()

# Create a DataFrame with binary predictions
predictions_df = pd.DataFrame(binary_predictions, columns=['Prediction'])

print(predictions_df)
# Out:
#      Prediction
# 0           1.0
# 1           0.0
# 2           1.0
# 3           1.0
# 4           1.0
# ..          ...
# 395         1.0
# 396         0.0
# 397         1.0
# 398         0.0
# 399         0.0
#
# [400 rows x 1 columns]

# %% [markdown]
# ### Step 4: Display a classification report with the y test data and predictions

# %%
# Print the classification report with the y test data and predictions
print(classification_report(y_test, binary_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.73      0.71       188
#            1       0.75      0.71      0.73       212
#
#     accuracy                           0.72       400
#    macro avg       0.72      0.72      0.72       400
# weighted avg       0.72      0.72      0.72       400

# %% [markdown]
# ---
# ## Discuss creating a recommendation system for student loans

# %% [markdown]
# Briefly answer the following questions in the space provided:
#
# 1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.
#
# 2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.
#
# 3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.

# %% [markdown]
# **1. Describe the data that you would need to collect to build a recommendation system to recommend student loan options for students. Explain why this data would be relevant and appropriate.**
#
# a.  Label - Does student repay loan or not
#
# b.  Features/Predictors:
#
# Income level:  Students with more money can repay their loans more quickly.
#
# College degree:  Students who majored in high earning professions can more easily repay loans compared to students in low paying professions.
#
# Credit score:  Does the person/student pay off their credit card debt?  A higher score may indicate that a student will pay off their debt and sooner.
#
# Terms of the student loan:  Higher interest rated are harder to pay back versus lower interest rates.
#
# Financial aid:  How much financial aid did the student receive?  It is harder to pay off more debt.
#
# Family and relationship status:  A student with dependents may have extra expenses.
#
#
#
# **2. Based on the data you chose to use in this recommendation system, would your model be using collaborative filtering, content-based filtering, or context-based filtering? Justify why the data you selected would be suitable for your choice of filtering method.**
#
# a.  Context-based filtering
# b.  These are objective scores/data versus preference-based or reliant on others who may be similar to the person/student.
#
#
# **3. Describe two real-world challenges that you would take into consideration while building a recommendation system for student loans. Explain why these challenges would be of concern for a student loan recommendation system.**
#
# a.  College degrees are not valued as highly as they used to be due in part to massive student debt and changing of societal values.  I would like a control group of non-students who did not graduate or go to school who went into the same profession as those who did graduate.  This would help me distinguish between professions wherein student loans can ultimately payoff versus professions where they are a waste/burden.
#
# b. Was the education on or off-campus or both?   Perhaps lower interest rates are more appealing to students who are present on campus to offset the drawbacks of the total expense.  They may also be investing more money into the university through other means such as room and board.
